# %%
import gymnasium as gym
from gymnasium.envs.registration import register
import toy_env as te
import numpy as np
from matplotlib import pyplot as plt

# %%
F1, F2 = 0.7, 0.2
p1, p2 = 0.2, 0.7

q = np.linspace(0,1,100)
p = q*p1+(1-q)*p2
F = (q*p1*F1+(1-q)*p2*F2)/(q*p1+(1-q)*p2)

plt.plot(p, F)

# %%
p_ = np.linspace(p1,p2,100)
F_ = (p1*p2/p)*((F2-F1)/(p1-p2))+(p1*F1-p2*F2)/(p1-p2)
plt.plot(p, F)
plt.xlabel('p_q')
plt.ylabel('F_q')
# Out:
# Text(0, 0.5, 'F_q')
